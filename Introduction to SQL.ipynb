# %% [markdown]
# ### Importing SQLite Module

# %%
import pandas as pd
import sqlite3

# %%
ls
# Out:
# Intro To SQL.ipynb         Untitled1.ipynb
# Introduction to SQL.ipynb  jobs.db
# Untitled.ipynb

# %% [markdown]
# ### Making Connection to the Database

# %%
conn = sqlite3.connect('jobs.db')

# %% [markdown]
# ### Creating a Cursor Instance

# %%
cursor = conn.cursor()

# %% [markdown]
# ### Reading an SQL Query Directly into a Pandas DataFrame

# %%
df = pd.read_sql_query("SELECT * FROM recent_grads LIMIT 5", conn)

# %%
df.head()
# Out:
#    index  Rank  Major_code                                      Major  \
# 0      0     1        2419                      PETROLEUM ENGINEERING
# 1      1     2        2416             MINING AND MINERAL ENGINEERING
# 2      2     3        2415                  METALLURGICAL ENGINEERING
# 3      3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      4     5        2405                       CHEMICAL ENGINEERING
#
#   Major_category  Total  Sample_size    Men  Women  ShareWomen      ...        \
# 0    Engineering   2339           36   2057    282    0.120564      ...
# 1    Engineering    756            7    679     77    0.101852      ...
# 2    Engineering    856            3    725    131    0.153037      ...
# 3    Engineering   1258           16   1123    135    0.107313      ...
# 4    Engineering  32260          289  21239  11021    0.341631      ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %% [markdown]
# ### Checking the Columns of the Table

# %%
df.columns
# Out:
# Index([u'index', u'Rank', u'Major_code', u'Major', u'Major_category', u'Total',
#        u'Sample_size', u'Men', u'Women', u'ShareWomen', u'Employed',
#        u'Full_time', u'Part_time', u'Full_time_year_round', u'Unemployed',
#        u'Unemployment_rate', u'Median', u'P25th', u'P75th', u'College_jobs',
#        u'Non_college_jobs', u'Low_wage_jobs'],
#       dtype='object')

# %% [markdown]
# ### Checking Data Tyeps of All the Columns

# %%
df.dtypes
# Out:
# index                     int64
# Rank                      int64
# Major_code                int64
# Major                    object
# Major_category           object
# Total                     int64
# Sample_size               int64
# Men                       int64
# Women                     int64
# ShareWomen              float64
# Employed                  int64
# Full_time                 int64
# Part_time                 int64
# Full_time_year_round      int64
# Unemployed                int64
# Unemployment_rate       float64
# Median                    int64
# P25th                     int64
# P75th                     int64
# College_jobs              int64
# Non_college_jobs          int64
# Low_wage_jobs             int64
# dtype: object

# %% [markdown]
# ### Checking the Pragma of the Table

# %%
query = "PRAGMA TABLE_INFO(recent_grads)"

# %%
pd.read_sql_query(query, conn)
# Out:
#     cid                  name     type  notnull dflt_value  pk
# 0     0                 index  INTEGER        0       None   0
# 1     1                  Rank  INTEGER        0       None   0
# 2     2            Major_code  INTEGER        0       None   0
# 3     3                 Major     TEXT        0       None   0
# 4     4        Major_category     TEXT        0       None   0
# 5     5                 Total  INTEGER        0       None   0
# 6     6           Sample_size  INTEGER        0       None   0
# 7     7                   Men  INTEGER        0       None   0
# 8     8                 Women  INTEGER        0       None   0
# 9     9            ShareWomen     REAL        0       None   0
# 10   10              Employed  INTEGER        0       None   0
# 11   11             Full_time  INTEGER        0       None   0
# 12   12             Part_time  INTEGER        0       None   0
# 13   13  Full_time_year_round  INTEGER        0       None   0
# ...

# %% [markdown]
# ### Exerises

# %%
query1 = "SELECT Major, ShareWomen\
          FROM recent_grads\
          WHERE ShareWomen < 0.5"

# %%
pd.read_sql_query(query1, conn).head()
# Out:
#                                        Major  ShareWomen
# 0                      PETROLEUM ENGINEERING    0.120564
# 1             MINING AND MINERAL ENGINEERING    0.101852
# 2                  METALLURGICAL ENGINEERING    0.153037
# 3  NAVAL ARCHITECTURE AND MARINE ENGINEERING    0.107313
# 4                       CHEMICAL ENGINEERING    0.341631

# %%
query1 = "SELECT *\
          FROM recent_grads\
          WHERE ShareWomen < 0.5"

# %%
pd.read_sql_query(query1, conn).head()
# Out:
#    index  Rank  Major_code                                      Major  \
# 0      0     1        2419                      PETROLEUM ENGINEERING
# 1      1     2        2416             MINING AND MINERAL ENGINEERING
# 2      2     3        2415                  METALLURGICAL ENGINEERING
# 3      3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      4     5        2405                       CHEMICAL ENGINEERING
#
#   Major_category  Total  Sample_size    Men  Women  ShareWomen      ...        \
# 0    Engineering   2339           36   2057    282    0.120564      ...
# 1    Engineering    756            7    679     77    0.101852      ...
# 2    Engineering    856            3    725    131    0.153037      ...
# 3    Engineering   1258           16   1123    135    0.107313      ...
# 4    Engineering  32260          289  21239  11021    0.341631      ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
query = "SELECT Major, Major_category, Median, ShareWomen\
         FROM recent_grads\
         WHERE ShareWomen >= 0.5 AND Median > 50000"

# %%
pd.read_sql_query(query, conn)
# Out:
#                Major           Major_category  Median  ShareWomen
# 0  ACTUARIAL SCIENCE                 Business   62000    0.535714
# 1   COMPUTER SCIENCE  Computers & Mathematics   53000    0.578766

# %%
query = "SELECT Major, Median, Unemployed\
         FROM recent_grads\
         WHERE Median > 10000 OR Unemployed < 1000\
         LIMIT 20"

# %%
pd.read_sql_query(query, conn)
# Out:
#                                         Major  Median  Unemployed
# 0                       PETROLEUM ENGINEERING  110000          37
# 1              MINING AND MINERAL ENGINEERING   75000          85
# 2                   METALLURGICAL ENGINEERING   73000          16
# 3   NAVAL ARCHITECTURE AND MARINE ENGINEERING   70000          40
# 4                        CHEMICAL ENGINEERING   65000        1672
# 5                         NUCLEAR ENGINEERING   65000         400
# 6                           ACTUARIAL SCIENCE   62000         308
# 7                  ASTRONOMY AND ASTROPHYSICS   62000          33
# 8                      MECHANICAL ENGINEERING   60000        4650
# 9                      ELECTRICAL ENGINEERING   60000        3895
# 10                       COMPUTER ENGINEERING   60000        2275
# 11                      AEROSPACE ENGINEERING   60000         794
# 12                     BIOMEDICAL ENGINEERING   60000        1019
# ...

# %%
query = "SELECT Major, Major_category, ShareWomen, Unemployment_rate\
         FROM recent_grads\
         WHERE ((Major_category = 'Engineering') AND (ShareWomen >= 0.5 OR Unemployment_rate < 0.051))"

# %%
pd.read_sql_query(query, conn)
# Out:
#                                          Major Major_category  ShareWomen  \
# 0                        PETROLEUM ENGINEERING    Engineering    0.120564
# 1                    METALLURGICAL ENGINEERING    Engineering    0.153037
# 2    NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering    0.107313
# 3                            MATERIALS SCIENCE    Engineering    0.310820
# 4    ENGINEERING MECHANICS PHYSICS AND SCIENCE    Engineering    0.183985
# 5     INDUSTRIAL AND MANUFACTURING ENGINEERING    Engineering    0.343473
# 6  MATERIALS ENGINEERING AND MATERIALS SCIENCE    Engineering    0.292607
# 7                    ENVIRONMENTAL ENGINEERING    Engineering    0.558548
# 8           INDUSTRIAL PRODUCTION TECHNOLOGIES    Engineering    0.750473
# 9        ENGINEERING AND INDUSTRIAL MANAGEMENT    Engineering    0.174123
#
#    Unemployment_rate
# 0           0.018381
# 1           0.024096
# 2           0.050125
# 3           0.023043
# 4           0.006334
# ...

# %%
query = "SELECT Major, ShareWomen, Unemployment_rate\
         FROM recent_grads\
         WHERE ShareWomen > 0.3 AND Unemployment_rate < 0.1\
         ORDER BY ShareWomen DESC"

# %%
pd.read_sql_query(query, conn).head()
# Out:
#                               Major  ShareWomen  Unemployment_rate
# 0         EARLY CHILDHOOD EDUCATION    0.967998           0.040105
# 1  MATHEMATICS AND COMPUTER SCIENCE    0.927807           0.000000
# 2              ELEMENTARY EDUCATION    0.923745           0.046586
# 3                   ANIMAL SCIENCES    0.910933           0.050862
# 4                        PHYSIOLOGY    0.906677           0.069163

# %%
query = "SELECT Major_category, Major, Unemployment_rate\
         FROM recent_grads\
         WHERE Major_category = 'Engineering' OR Major_category = 'Physical Sciences'\
         ORDER BY Unemployment_rate"

# %%
pd.read_sql_query(query, conn).head()
# Out:
#       Major_category                                      Major  \
# 0        Engineering  ENGINEERING MECHANICS PHYSICS AND SCIENCE
# 1        Engineering                      PETROLEUM ENGINEERING
# 2  Physical Sciences                 ASTRONOMY AND ASTROPHYSICS
# 3  Physical Sciences       ATMOSPHERIC SCIENCES AND METEOROLOGY
# 4        Engineering                          MATERIALS SCIENCE
#
#    Unemployment_rate
# 0           0.006334
# 1           0.018381
# 2           0.021167
# 3           0.022229
# 4           0.023043

# %%
query = "SELECT COUNT(Major)\
         FROM recent_grads\
         WHERE ShareWomen < 0.5"

# %%
pd.read_sql_query(query, conn)
# Out:
#    COUNT(Major)
# 0            76

# %%
query = "SELECT Major, Major_category, MIN(Median)\
         FROM recent_grads\
         WHERE Major_category = 'Engineering'"

# %%
pd.read_sql_query(query, conn)
# Out:
#           Major Major_category  MIN(Median)
# 0  ARCHITECTURE    Engineering        40000

# %%
query = "SELECT SUM(Total)\
         FROM recent_grads"

# %%
pd.read_sql_query(query, conn)
# Out:
#    SUM(Total)
# 0     6776015

# %%
query = "SELECT AVG(Total), MIN(Men), MAX(Women)\
         FROM recent_grads"

# %%
pd.read_sql_query(query, conn)
# Out:
#      AVG(Total)  MIN(Men)  MAX(Women)
# 0  39167.716763       119      307087

# %%
query = "SELECT COUNT(Major) as 'Number of Majors', MAX(Unemployment_rate) as 'Highest Unemployment Rate'\
         FROM recent_grads"

# %%
pd.read_sql_query(query, conn)
# Out:
#    Number of Majors  Highest Unemployment Rate
# 0               173                   0.177226

# %%
query = "SELECT COUNT(DISTINCT(Major)) as 'unique_majors',\
                COUNT(DISTINCT(Major_category)) as 'unique_major_categories',\
                COUNT(DISTINCT(Major_code)) as 'unique_major_codes'\
         FROM recent_grads"

# %%
pd.read_sql_query(query, conn)
# Out:
#    unique_majors  unique_major_categories  unique_major_codes
# 0            173                       16                 173

# %%
query = "SELECT Major, Major_category, (P75th - P25th) as 'quartile_spread'\
         FROM recent_grads\
         ORDER BY quartile_spread\
         LIMIT 20"

# %%
pd.read_sql_query(query, conn).head()
# Out:
#                        Major                       Major_category  \
# 0      MILITARY TECHNOLOGIES  Industrial Arts & Consumer Services
# 1  SCHOOL STUDENT COUNSELING                            Education
# 2            LIBRARY SCIENCE                            Education
# 3            COURT REPORTING                  Law & Public Policy
# 4               PHARMACOLOGY               Biology & Life Science
#
#    quartile_spread
# 0                0
# 1             2000
# 2             2000
# 3             4000
# 4             5000

# %%
query = "SELECT Major_category, AVG(ShareWomen)\
         FROM recent_grads\
         GROUP BY Major_category"

# %%
pd.read_sql_query(query, conn).head()
# Out:
#                     Major_category  AVG(ShareWomen)
# 0  Agriculture & Natural Resources         0.617938
# 1                             Arts         0.561851
# 2           Biology & Life Science         0.584518
# 3                         Business         0.405063
# 4      Communications & Journalism         0.643835

# %%
query = "SELECT * FROM recent_grads"

# %%
query = "SELECT Major_category, (AVG(Employed)/AVG(Total)) as Share_employed\
         FROM recent_grads\
         GROUP BY Major_category\
         ORDER BY 'Share_employed' DESC"

# %%
pd.read_sql_query(query, conn).head()
# Out:
#                     Major_category  Share_employed
# 0  Agriculture & Natural Resources        0.836986
# 1                             Arts        0.806748
# 2           Biology & Life Science        0.667157
# 3                         Business        0.835966
# 4      Communications & Journalism        0.842229

# %%
query = "SELECT Major_category, AVG(Low_wage_jobs) / AVG(Total) AS share_low_wage\
         FROM recent_grads\
         GROUP BY Major_category\
         HAVING share_low_wage > .1;"

# %%
pd.read_sql_query(query, conn)
# Out:
#                         Major_category  share_low_wage
# 0                                 Arts        0.168331
# 1          Communications & Journalism        0.126324
# 2            Humanities & Liberal Arts        0.132087
# 3  Industrial Arts & Consumer Services        0.115713
# 4                  Law & Public Policy        0.115685
# 5             Psychology & Social Work        0.116934
# 6                       Social Science        0.102233

# %%
query = "SELECT ROUND(ShareWomen, 4), Major_category\
         FROM recent_grads\
         LIMIT 10"

# %%
pd.read_sql_query(query, conn)
# Out:
#    ROUND(ShareWomen, 4)     Major_category
# 0                0.1206        Engineering
# 1                0.1019        Engineering
# 2                0.1530        Engineering
# 3                0.1073        Engineering
# 4                0.3416        Engineering
# 5                0.1450        Engineering
# 6                0.5357           Business
# 7                0.4414  Physical Sciences
# 8                0.1398        Engineering
# 9                0.4378        Engineering

# %%
query = "SELECT Major_category, ROUND(AVG(College_jobs)/AVG(Total), 3) AS share_degree_jobs\
         FROM recent_grads\
         GROUP BY Major_category\
         HAVING share_degree_jobs < 0.3\
         ORDER BY share_degree_jobs"

# %%
pd.read_sql_query(query, conn)
# Out:
#                         Major_category  share_degree_jobs
# 0                             Business              0.114
# 1                  Law & Public Policy              0.163
# 2                       Social Science              0.215
# 3          Communications & Journalism              0.220
# 4      Agriculture & Natural Resources              0.248
# 5  Industrial Arts & Consumer Services              0.249
# 6                                 Arts              0.265
# 7            Humanities & Liberal Arts              0.270

# %%
query = "PRAGMA TABLE_INFO(recent_grads)"

# %%
pd.read_sql_query(query, conn)
# Out:
#     cid                  name     type  notnull dflt_value  pk
# 0     0                 index  INTEGER        0       None   0
# 1     1                  Rank  INTEGER        0       None   0
# 2     2            Major_code  INTEGER        0       None   0
# 3     3                 Major     TEXT        0       None   0
# 4     4        Major_category     TEXT        0       None   0
# 5     5                 Total  INTEGER        0       None   0
# 6     6           Sample_size  INTEGER        0       None   0
# 7     7                   Men  INTEGER        0       None   0
# 8     8                 Women  INTEGER        0       None   0
# 9     9            ShareWomen     REAL        0       None   0
# 10   10              Employed  INTEGER        0       None   0
# 11   11             Full_time  INTEGER        0       None   0
# 12   12             Part_time  INTEGER        0       None   0
# 13   13  Full_time_year_round  INTEGER        0       None   0
# ...

# %%
query = "SELECT Major_category, CAST(SUM(Women) as Float) / CAST(SUM(Total) as Float) AS SW\
         FROM recent_grads\
         GROUP BY Major_category\
         ORDER BY SW"

# %%
pd.read_sql_query(query, conn).head()
# Out:
#                         Major_category        SW
# 0                  Law & Public Policy  0.030585
# 1                             Business  0.084743
# 2  Industrial Arts & Consumer Services  0.160249
# 3              Computers & Mathematics  0.209356
# 4                          Engineering  0.219596

# %%
query1 = "SELECT AVG(ShareWomen)\
          FROM recent_grads"

# %%
query2 = "SELECT Major, ShareWomen\
          FROM recent_grads\
          WHERE ShareWomen > (SELECT AVG(ShareWomen) FROM recent_grads)"

# %%
pd.read_sql_query(query2, conn).head()
# Out:
#                                 Major  ShareWomen
# 0                   ACTUARIAL SCIENCE    0.535714
# 1                    COMPUTER SCIENCE    0.578766
# 2           ENVIRONMENTAL ENGINEERING    0.558548
# 3                             NURSING    0.896019
# 4  INDUSTRIAL PRODUCTION TECHNOLOGIES    0.750473

# %%
query = "SELECT Major, Unemployment_rate\
         FROM recent_grads\
         WHERE Unemployment_rate < (SELECT AVG(Unemployment_rate) FROM recent_grads)\
         ORDER BY Unemployment_rate"

# %%
pd.read_sql_query(query, conn).head(10)
# Out:
#                                         Major  Unemployment_rate
# 0            MATHEMATICS AND COMPUTER SCIENCE           0.000000
# 1                                      BOTANY           0.000000
# 2                                SOIL SCIENCE           0.000000
# 3  EDUCATIONAL ADMINISTRATION AND SUPERVISION           0.000000
# 4   ENGINEERING MECHANICS PHYSICS AND SCIENCE           0.006334
# 5                             COURT REPORTING           0.011690
# 6               MATHEMATICS TEACHER EDUCATION           0.016203
# 7                       PETROLEUM ENGINEERING           0.018381
# 8                         GENERAL AGRICULTURE           0.019642
# 9                  ASTRONOMY AND ASTROPHYSICS           0.021167

# %%
SELECT CAST(COUNT(*) as float)/CAST((SELECT COUNT(*) from recent_grads) as float) proportion_abv_avg
FROM recent_grads
WHERE ShareWomen > (SELECT AVG(ShareWomen) from recent_grads)

# %%
query = "SELECT CAST(COUNT(*) as float)/CAST((SELECT COUNT(*) FROM recent_grads) as float) proportion_abv_avg\
         FROM recent_grads\
         WHERE ShareWomen > (SELECT AVG(ShareWomen) FROM recent_grads)"

# %%
pd.read_sql_query(query, conn)
# Out:
#    proportion_abv_avg
# 0            0.526012

# %%
# number of rows above average sharewomen / number of total rows

# ONE = (SELECT AVG(ShareWomen) FROM recent_grads)

# TWO = (SELECT COUNT(*) FROM recent_grads)

# %%
# SELECT COUNT(*) / (TWO)
# FROM recent_grads
# WHERE ShareWomen > ONE

# %%
query = "SELECT Major, Major_category\
         FROM recent_grads\
         WHERE Major_category IN ('Business', 'Engineering')\
         LIMIT 10"

# %%
pd.read_sql_query(query, conn)
# Out:
#                                        Major Major_category
# 0                      PETROLEUM ENGINEERING    Engineering
# 1             MINING AND MINERAL ENGINEERING    Engineering
# 2                  METALLURGICAL ENGINEERING    Engineering
# 3  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4                       CHEMICAL ENGINEERING    Engineering
# 5                        NUCLEAR ENGINEERING    Engineering
# 6                          ACTUARIAL SCIENCE       Business
# 7                     MECHANICAL ENGINEERING    Engineering
# 8                     ELECTRICAL ENGINEERING    Engineering
# 9                       COMPUTER ENGINEERING    Engineering

# %%
query = "SELECT Major_category, SUM(Total) as sum\
         FROM recent_grads\
         GROUP BY Major_category\
         ORDER BY sum DESC\
         LIMIT 5"

# %%
pd.read_sql_query(query, conn)
# Out:
#               Major_category      sum
# 0                   Business  1302376
# 1  Humanities & Liberal Arts   713468
# 2                  Education   559129
# 3                Engineering   537583
# 4             Social Science   529966

# %%
query = "SELECT Major, Major_category\
         FROM recent_grads\
         WHERE Major_category in (SELECT Major_category\
                                  FROM recent_grads\
                                  GROUP BY Major_category\
                                  ORDER BY SUM(Total) DESC\
                                  LIMIT 5)"

# %%
pd.read_sql_query(query, conn).head()
# Out:
#                                        Major Major_category
# 0                      PETROLEUM ENGINEERING    Engineering
# 1             MINING AND MINERAL ENGINEERING    Engineering
# 2                  METALLURGICAL ENGINEERING    Engineering
# 3  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4                       CHEMICAL ENGINEERING    Engineering

# %%
inner_query = "SELECT AVG(CAST(Sample_size as Float)/CAST(Total as Float))\
               FROM recent_grads"

pd.read_sql_query(inner_query, conn)
# Out:
#    AVG(CAST(Sample_size as Float)/CAST(Total as Float))
# 0                                           0.009086

# %%
query = "SELECT Major, Major_category, CAST(Sample_size as float)/CAST(Total as float) ratio\
         FROM recent_grads\
         WHERE ratio > (SELECT AVG(CAST(Sample_size as float)/CAST(Total as float)) avg_ratio\ 
                        FROM recent_grads)
# Out:
#   File "<ipython-input-292-f61f3e2a64e5>", line 1
#     query = "SELECT Major, Major_category, CAST(Sample_size as float)/CAST(Total as float) ratio         FROM recent_grads         WHERE ratio > (SELECT AVG(CAST(Sample_size as float)/CAST(Total as float)) avg_ratio\
#                                                                                                                                                                                                                         ^
# SyntaxError: EOL while scanning string literal

# %%
pd.read_sql_query(query, conn)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-293-0cec875daf72> in <module>()
# ----> 1 pd.read_sql_query(query, conn)
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/io/sql.pyc in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330     return pandas_sql.read_query(
#     331         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 332         parse_dates=parse_dates, chunksize=chunksize)
#     333
#     334
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/io/sql.pyc in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1437
#    1438         args = _convert_params(sql, params)
# -> 1439         cursor = self.execute(*args)
#    1440         columns = [col_desc[0] for col_desc in cursor.description]
#    1441
#
# ...

# %%
subquery = "SELECT AVG(CAST(Sample_size as Float)/CAST(Total as Float)) avg_ratio\
            FROM recent_grads"

pd.read_sql_query(subquery, conn)
# Out:
#    avg_ratio
# 0   0.009086

# %%
query = "SELECT Major, Major_category, CAST(Sample_size as Float)/CAST(Total as Float) ratio\
         FROM recent_grads\
         WHERE ratio > (SELECT AVG(CAST(Sample_size as Float)/CAST(Total as Float)) avg_ratio\
                        FROM recent_grads)"

# %%
pd.read_sql_query(query, conn).head()
# Out:
#                                        Major Major_category     ratio
# 0                      PETROLEUM ENGINEERING    Engineering  0.015391
# 1             MINING AND MINERAL ENGINEERING    Engineering  0.009259
# 2  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering  0.012719
# 3                          ACTUARIAL SCIENCE       Business  0.013503
# 4                     MECHANICAL ENGINEERING    Engineering  0.011280
